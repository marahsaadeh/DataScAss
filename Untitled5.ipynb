# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
df=pd.read_csv('yellow_tripdata_2019-02 (1).csv')

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1     01/02/2019 00:59      01/02/2019 01:07                1
# 1               1     01/02/2019 00:33      01/02/2019 01:03                1
# 2               1     01/02/2019 00:09      01/02/2019 00:09                1
# 3               1     01/02/2019 00:45      01/02/2019 00:51                1
# 4               1     01/02/2019 00:25      01/02/2019 00:28                1
# ...           ...                  ...                   ...              ...
# 1048570         1     05/02/2019 08:28      05/02/2019 08:48                1
# 1048571         1     05/02/2019 08:50      05/02/2019 09:02                1
# 1048572         1     05/02/2019 08:00      05/02/2019 08:14                1
# 1048573         1     05/02/2019 08:20      05/02/2019 08:28                1
# 1048574         1     05/02/2019 08:34      05/02/2019 08:39                1
#
# ...

# %%
df.dtypes
# Out:
# VendorID                   int64
# tpep_pickup_datetime      object
# tpep_dropoff_datetime     object
# passenger_count            int64
# trip_distance            float64
# RatecodeID                 int64
# store_and_fwd_flag        object
# PULocationID               int64
# DOLocationID               int64
# payment_type               int64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# congestion_surcharge     float64
# dtype: object

# %%
def trip_duration(df):
    df['The_trip_duration_min'] =  pd.to_datetime(df['tpep_dropoff_datetime']) - pd.to_datetime(df['tpep_pickup_datetime'])    
    return df
df =trip_duration(df)

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1     01/02/2019 00:59      01/02/2019 01:07                1
# 1               1     01/02/2019 00:33      01/02/2019 01:03                1
# 2               1     01/02/2019 00:09      01/02/2019 00:09                1
# 3               1     01/02/2019 00:45      01/02/2019 00:51                1
# 4               1     01/02/2019 00:25      01/02/2019 00:28                1
# ...           ...                  ...                   ...              ...
# 1048570         1     05/02/2019 08:28      05/02/2019 08:48                1
# 1048571         1     05/02/2019 08:50      05/02/2019 09:02                1
# 1048572         1     05/02/2019 08:00      05/02/2019 08:14                1
# 1048573         1     05/02/2019 08:20      05/02/2019 08:28                1
# 1048574         1     05/02/2019 08:34      05/02/2019 08:39                1
#
# ...

# %%
def add_hour_day(df):
    df['hour_of_day'] = pd.to_datetime(df['tpep_pickup_datetime']).apply(lambda x: x.strftime("%H"))
    df['day_of_week'] = pd.to_datetime(df['tpep_pickup_datetime']).apply(lambda x: x.strftime("%A"))
    return df
df = add_hour_day(df)

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1     01/02/2019 00:59      01/02/2019 01:07                1
# 1               1     01/02/2019 00:33      01/02/2019 01:03                1
# 2               1     01/02/2019 00:09      01/02/2019 00:09                1
# 3               1     01/02/2019 00:45      01/02/2019 00:51                1
# 4               1     01/02/2019 00:25      01/02/2019 00:28                1
# ...           ...                  ...                   ...              ...
# 1048570         1     05/02/2019 08:28      05/02/2019 08:48                1
# 1048571         1     05/02/2019 08:50      05/02/2019 09:02                1
# 1048572         1     05/02/2019 08:00      05/02/2019 08:14                1
# 1048573         1     05/02/2019 08:20      05/02/2019 08:28                1
# 1048574         1     05/02/2019 08:34      05/02/2019 08:39                1
#
# ...

# %%
time_trip_duration=df['The_trip_duration_min'].dt.components
df["time_trip_duration"]=time_trip_duration["minutes"]

# %%
def compute_predictions(df):
    predictions = df.groupby(['PULocationID', 'DOLocationID', 'day_of_week', 'hour_of_day'])['time_trip_duration']
    mean = predictions.mean()
    standard_deviation = predictions.std()
    t_score_value= stats.t.ppf(0.975, len(df) - 1)
    pred = pd.DataFrame({'mean_trip_duration': mean, 'margin_of_error': t_score_value * standard_deviation / np.sqrt(len(df))})
    return pred

# %%
z_value = stats.norm.ppf(0.9505)
z_value
# Out:
# 1.649721063683362

# %%
dataset=compute_predictions(df)
dataset
# Out:
#                                                    mean_trip_duration  \
# PULocationID DOLocationID day_of_week hour_of_day
# 1            1            Saturday    03                     0.000000
#                                       06                     0.400000
#                                       07                     4.000000
#                                       09                     0.000000
#                                       11                     0.000000
# ...                                                               ...
# 265          265          Wednesday   19                     5.500000
#                                       20                     2.750000
#                                       21                     1.500000
#                                       22                     2.250000
#                                       23                     0.666667
#
#                                                    margin_of_error
# ...
